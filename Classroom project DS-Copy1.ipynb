# %%
import pandas as pd
df=pd.read_csv("C:/Dataset/testdemographics.csv")

# %%
df
# Out:
#                             customerid                   birthdate  \
# 0     8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1     8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2     8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3     8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4     8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
# ...                                ...                         ...
# 1482  8a858fc25bafabdc015bb47fda0323e5  1976-04-13 00:00:00.000000
# 1483  8a858e245c214660015c3397e4db389a  1990-10-24 00:00:00.000000
# 1484  8a858e8b5bc9e7e6015bcd7374077f0c  1988-06-12 00:00:00.000000
# 1485  8a858f2e5c699f3a015c77aa22ed7f23  1974-03-23 00:00:00.000000
# 1486  8a858fde580afd48015818eda53830c8  1987-02-16 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0              Savings       5.296628      7.593965     Heritage Bank
# ...

# %%
df.describe()
# Out:
#        longitude_gps  latitude_gps
# count    1487.000000   1487.000000
# mean        4.433701      7.134664
# std         6.322600      3.016042
# min      -149.033700    -74.005974
# 25%         3.355046      6.480314
# 50%         3.583009      6.620080
# 75%         6.562512      7.431567
# max        39.815590     40.895322

# %%
df.describe(include='all')
# Out:
#                               customerid                   birthdate  \
# count                               1487                        1487
# unique                              1484                        1347
# top     8a858f2e5c699f3a015c6e10b65607c9  1983-10-01 00:00:00.000000
# freq                                   2                           3
# mean                                 NaN                         NaN
# std                                  NaN                         NaN
# min                                  NaN                         NaN
# 25%                                  NaN                         NaN
# 50%                                  NaN                         NaN
# 75%                                  NaN                         NaN
# max                                  NaN                         NaN
#
#        bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1487 entries, 0 to 1486
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  1487 non-null   object
#  1   birthdate                   1487 non-null   object
#  2   bank_account_type           1487 non-null   object
#  3   longitude_gps               1487 non-null   float64
#  4   latitude_gps                1487 non-null   float64
#  5   bank_name_clients           1487 non-null   object
#  6   bank_branch_clients         14 non-null     object
#  7   employment_status_clients   1270 non-null   object
#  8   level_of_education_clients  210 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 104.7+ KB

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['bank_account_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['bank_name_clients'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['level_of_education_clients'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='level_of_education_clients'>

# %%
print(df.iloc[:2, :5])
# Out:
#                          customerid                   birthdate  \
# 0  8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1  8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
#
#   bank_account_type  longitude_gps  latitude_gps
# 0           Savings       5.296628      7.593965
# 1           Savings       3.294513      6.596602

# %%
df
# Out:
#                             customerid                   birthdate  \
# 0     8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1     8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2     8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3     8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4     8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
# ...                                ...                         ...
# 1482  8a858fc25bafabdc015bb47fda0323e5  1976-04-13 00:00:00.000000
# 1483  8a858e245c214660015c3397e4db389a  1990-10-24 00:00:00.000000
# 1484  8a858e8b5bc9e7e6015bcd7374077f0c  1988-06-12 00:00:00.000000
# 1485  8a858f2e5c699f3a015c77aa22ed7f23  1974-03-23 00:00:00.000000
# 1486  8a858fde580afd48015818eda53830c8  1987-02-16 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 0              Savings       5.296628      7.593965     Heritage Bank
# ...

# %%
print(df.loc[:,'bank_account_type': 'bank_name_clients'])
# Out:
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients
# 0              Savings       5.296628      7.593965     Heritage Bank
# 1              Savings       3.294513      6.596602               UBA
# 2              Savings       8.501912      7.729364        First Bank
# 3              Savings       3.318904      6.681595               UBA
# 4              Savings       6.354624      4.949031        First Bank
# ...                ...            ...           ...               ...
# 1482           Savings       3.481190      6.442728           GT Bank
# 1483           Savings       4.738209      8.179723           GT Bank
# 1484           Savings       3.424825      6.455802        First Bank
# 1485           Savings       3.318851      7.113212              FCMB
# 1486           Savings       3.372462      6.563372      Stanbic IBTC
#
# [1487 rows x 4 columns]

# %%
print(df.loc[:,'bank_account_type'])
# Out:
# 0       Savings
# 1       Savings
# 2       Savings
# 3       Savings
# 4       Savings
#          ...
# 1482    Savings
# 1483    Savings
# 1484    Savings
# 1485    Savings
# 1486    Savings
# Name: bank_account_type, Length: 1487, dtype: object

# %%
df.loc[:, ['bank_account_type', 'bank_name_clients', 'employment_status_clients', 'level_of_education_clients']]
# Out:
#      bank_account_type bank_name_clients employment_status_clients  \
# 0              Savings     Heritage Bank                 Permanent
# 1              Savings               UBA                 Permanent
# 2              Savings        First Bank                 Permanent
# 3              Savings               UBA                 Permanent
# 4              Savings        First Bank             Self-Employed
# ...                ...               ...                       ...
# 1482           Savings           GT Bank                 Permanent
# 1483           Savings           GT Bank                 Permanent
# 1484           Savings        First Bank                 Permanent
# 1485           Savings              FCMB                 Permanent
# 1486           Savings      Stanbic IBTC                 Permanent
#
#      level_of_education_clients
# 0                           NaN
# 1                           NaN
# 2                           NaN
# ...

# %%
df.query("level_of_education_clients == 'Graduate'")
# Out:
#                             customerid                   birthdate  \
# 11    8a858e5856b7840c0156bb256d6e0e6a  1991-01-11 00:00:00.000000
# 13    8a858e585693982b015698da71ca5342  1975-12-07 00:00:00.000000
# 25    8a858ed75732b68101574d1614f23803  1983-07-28 00:00:00.000000
# 41    8a858fd3552c756201553571d2fe62e3  1988-12-24 00:00:00.000000
# 56    8a858fa057e2a0a50157f1ffa5f228a0  1992-03-07 00:00:00.000000
# ...                                ...                         ...
# 1469  8a8589a7545186b1015468c4ca294b60  1979-01-31 00:00:00.000000
# 1473  8a858ee55830c4b90158337542ab18a1  1995-05-31 00:00:00.000000
# 1474  8a85881053bc33670153c79e8e84571a  1984-05-11 00:00:00.000000
# 1480  8a858e0256b781d80156b8f2d33c4f27  1986-09-24 00:00:00.000000
# 1486  8a858fde580afd48015818eda53830c8  1987-02-16 00:00:00.000000
#
#      bank_account_type  longitude_gps  latitude_gps bank_name_clients  \
# 11               Other       3.309942      6.461257           GT Bank
# ...

# %%
df.isnull().sum()
# Out:
# customerid                       0
# birthdate                        0
# bank_account_type                0
# longitude_gps                    0
# latitude_gps                     0
# bank_name_clients                0
# bank_branch_clients           1473
# employment_status_clients      217
# level_of_education_clients    1277
# dtype: int64
